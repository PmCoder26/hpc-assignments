# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("graph_result.txt")
print("Execution Results:")
print(df)

# Time graph
plt.figure(figsize=(10, 5))
plt.plot(df.N, df.SEQ_TIME, label="Serial", marker='o')
plt.plot(df.N, df.PAR_TIME, label="Parallel", marker='x')
plt.xscale('log')
plt.yscale('log')
plt.xlabel("N (log scale)")
plt.ylabel("Time (ms, log scale)")
plt.title("Reduction Time: Serial vs Parallel")
plt.legend()
plt.grid(True)
plt.show()

# Speedup
plt.figure(figsize=(10, 5))
plt.plot(df.N, df.SPEEDUP, label="Speedup", marker='o', color='green')
plt.xscale('log')
plt.xlabel("N (log scale)")
plt.ylabel("Speedup (Serial/Parallel)")
plt.title("Speedup vs Problem Size")
plt.legend()
plt.grid(True)
plt.show()

# Efficiency graph
plt.figure(figsize=(10, 5))
plt.plot(df.N, df.EFFICIENCY, label="Efficiency", marker='o', color='red')
plt.xscale('log')
plt.xlabel("N (log scale)")
plt.ylabel("Efficiency")
plt.title("Efficiency vs Problem Size")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Execution Results:
#       N  SEQ_TIME  PAR_TIME   SPEEDUP  EFFICIENCY
# 0    10  0.000007  0.000539  0.012184    0.001523
# 1    25  0.000032  0.000043  0.728417    0.091052
# 2    35  0.000056  0.000056  1.008260    0.126032
# 3  1000  0.003323  0.001217  2.730790    0.341349
# 4  2000  0.006470  0.001896  3.412360    0.426544

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("sort_output.txt")
print("Execution Results:")
print(df)

# Time graph
plt.figure(figsize=(10, 5))
plt.plot(df.N, df.SEQ_TIME, label="Serial", marker='o')
plt.plot(df.N, df.PAR_TIME, label="Parallel", marker='x')
plt.xscale('log')
plt.yscale('log')
plt.xlabel("N (log scale)")
plt.ylabel("Time (ms, log scale)")
plt.title("Sorting Time: Serial vs Parallel")
plt.legend()
plt.grid(True)
plt.show()

# Speedup
plt.figure(figsize=(10, 5))
plt.plot(df.N, df.SPEEDUP, label="Speedup", marker='o', color='green')
plt.xscale('log')
plt.xlabel("N (log scale)")
plt.ylabel("Speedup (Serial/Parallel)")
plt.title("Speedup vs Problem Size")
plt.legend()
plt.grid(True)
plt.show()

# Efficiency graph
plt.figure(figsize=(10, 5))
plt.plot(df.N, df.EFFICIENCY, label="Efficiency", marker='o', color='red')
plt.xscale('log')
plt.xlabel("N (log scale)")
plt.ylabel("Efficiency")
plt.title("Efficiency vs Problem Size")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Execution Results:
#        N  SEQ_TIME  PAR_TIME   SPEEDUP  EFFICIENCY
# 0     10  0.000003  0.090037  0.000037    0.000002
# 1    100  0.000071  0.000376  0.188205    0.011763
# 2    500  0.001319  0.001517  0.869364    0.054335
# 3  10000  0.353807  0.099090  3.570560    0.223160
# 4  20000  1.464310  0.359102  4.077700    0.254856

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("reduction_result.txt")
print("Execution Results:")
print(df)

# Time graph
plt.figure(figsize=(10, 5))
plt.plot(df.N, df.SERIAL, label="Serial", marker='o')
plt.plot(df.N, df.PARALLEL, label="Parallel", marker='x')
plt.xscale('log')
plt.yscale('log')
plt.xlabel("N (log scale)")
plt.ylabel("Time (ms, log scale)")
plt.title("Reduction Time: Serial vs Parallel")
plt.legend()
plt.grid(True)
plt.show()

# Speedup
plt.figure(figsize=(10, 5))
plt.plot(df.N, df.SPEEDUP, label="Speedup", marker='o', color='green')
plt.xscale('log')
plt.xlabel("N (log scale)")
plt.ylabel("Speedup (Serial/Parallel)")
plt.title("Speedup vs Problem Size")
plt.legend()
plt.grid(True)
plt.show()

# Efficiency graph
plt.figure(figsize=(10, 5))
plt.plot(df.N, df.EFFICIENCY, label="Efficiency", marker='o', color='red')
plt.xscale('log')
plt.xlabel("N (log scale)")
plt.ylabel("Efficiency")
plt.title("Efficiency vs Problem Size")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Execution Results:
#          N     SERIAL   PARALLEL    SPEEDUP    EFFICIENCY
# 0     1000   0.002785  39.363100   0.000071  2.763730e-08
# 1    10000   0.029959   0.184751   0.162159  6.334330e-05
# 2   100000   0.267722   0.240750   1.112030  4.343880e-04
# 3  1000000   2.770970   0.510816   5.424600  2.118990e-03
# 4  5000000  13.682900   0.954402  14.336600  5.600250e-03

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("mandelbrot_result.txt")

# 1. Time
plt.plot(df.SIZE, df.CPU_TIME, label="CPU", marker='o')
plt.plot(df.SIZE, df.GPU_TIME, label="GPU", marker='x')
plt.xlabel("Size")
plt.ylabel("Time (ms)")
plt.title("Mandelbrot Execution Time")
plt.legend()
plt.show()

# 2. Speedup
plt.plot(df.SIZE, df.SPEEDUP, label="Speedup", color='green', marker='o')
plt.xlabel("Size")
plt.ylabel("Speedup")
plt.legend()
plt.show()

# 3. Efficiency
plt.plot(df.SIZE, df.EFFICIENCY, label="Efficiency", color='red', marker='o')
plt.xlabel("Size")
plt.ylabel("Efficiency")
plt.legend()
plt.show()
